# %% [markdown]
# ## TOPICS
#     - string functions
#     -dictionary, set, tuple
#     -args, kwargs
#     -import modules
#     -loops

# %%
#1
name="ananya"
type(name)
# Out:
# str

# %%
name[0]
# Out:
# 'a'

# %%
#2 
print("hey", "hello")
# Out:
# hey hello

# %%
#3 (for and in case)
x = "college is going to suck"
for item in x:
    print(item)
# Out:
# c
# o
# l
# l
# e
# g
# e
#
# i
# s
#
# g
# o
# i
# n
# g
#
# t
# o
#
# s
# u
# c
# k

# %%
#4
name.upper()
# Out:
# 'ANANYA'

# %%
#5
name.lower()
# Out:
# 'ananya'

# %%
#6
z= " laptop   "
z
# Out:
# ' laptop   '

# %%
#7 (this function helps to remove the space bars from the input)
y= " lappy "
y.strip()
# Out:
# 'lappy'

# %%
#8 (this functions helps in splitting the names into different strings)
names= "ananya, sanjay, mimo, memo".split()
names
# Out:
# ['ananya,', 'sanjay,', 'mimo,', 'memo']

# %%
#9
names[3]
# Out:
# 'memo'

# %%
#10
x= "ananya "
y= " kumar"
x+y
# Out:
# 'ananya  kumar'

# %%
#11 (CARE TO EXPLAIN) 
# 
a= 2.3132
b= 4.3121
myFavNum= "my fav number {}"
fav_nums= "my fav numbers are {aa:.2f}, and {bb: .2f}"
fav_nums.format(aa=a, bb=b)
# Out:
# 'my fav numbers are 2.31, and  4.31'

# %%
a= 2.3132
b= 4.3121
myFavNum= "my fav number {}"
fav_nums= "my fav numbers are {aa:.2f}, and {bb: .2f}"
fav_nums.format(aa=a,bb=b)
# Out:
# 'my fav numbers are 2.31, and  4.31'

# %%
#12 (format helps in filling in the curly brackets with the given information)
ac= "hello my name is {} and i live in {} currently studying {}"
ac.format("anu", "India", "Biotechnology")
# Out:
# 'hello my name is anu and i live in India currently studying Biotechnology'

# %%
# another example
blood_group="my blood group {}"
blood_group.format("O+ve")
# Out:
# 'my blood group O+ve'

# %%
#13 (helps to count the number of alphabets in the given phrase or in the seleted portion)
ac.count("a")
# Out:
# 2

# %%
#14 (this helps to fins the specific aplhabet in the given selceted protion)
ac.count("i", 0, 20)
# Out:
# 1

# %%
#15
txt= "hey there how are you doing and u better not be busy for me."
print(txt.index("be"))
# Out:
# 34

# %%
#16 (for/in cases {for loop})
name= "sanjay_ananya"
for item in name:
    print(item)
# Out:
# s
# a
# n
# j
# a
# y
# _
# a
# n
# a
# n
# y
# a

# %%
#17 (for/in case for students and subtracting (-30) from the values)
classes= [101, 29, 30, 6, 392]
for student in classes:
    student=student-5
    print(student)
# Out:
# 96
# 24
# 25
# 1
# 387

# %%
## for bank manager to deduct some shares because of bankruptcy
company= [1000340292, 1201029838493, 2029483020, 474829201, 37478383292, 3838392902]
for employees in company:
    employees= employees-999999999
    print(employees)
# Out:
# 340293
# 1200029838494
# 1029483021
# -525170798
# 36478383293
# 2838392903

# %%
#18 (printing a pattern)
for i in range(1,8):
    for j in range (2,10):
        print((i+j)*"$")
# Out:
# $$$
# $$$$
# $$$$$
# $$$$$$
# $$$$$$$
# $$$$$$$$
# $$$$$$$$$
# $$$$$$$$$$
# $$$$
# $$$$$
# $$$$$$
# $$$$$$$
# $$$$$$$$
# $$$$$$$$$
# $$$$$$$$$$
# $$$$$$$$$$$
# $$$$$
# $$$$$$
# $$$$$$$
# $$$$$$$$
# $$$$$$$$$
# $$$$$$$$$$
# $$$$$$$$$$$
# $$$$$$$$$$$$
# $$$$$$
# $$$$$$$
# $$$$$$$$
# $$$$$$$$$
# $$$$$$$$$$
# $$$$$$$$$$$
# $$$$$$$$$$$$
# $$$$$$$$$$$$$
# $$$$$$$
# $$$$$$$$
# $$$$$$$$$
# $$$$$$$$$$
# $$$$$$$$$$$
# $$$$$$$$$$$$
# $$$$$$$$$$$$$
# $$$$$$$$$$$$$$
# $$$$$$$$
# $$$$$$$$$
# $$$$$$$$$$
# $$$$$$$$$$$
# $$$$$$$$$$$$
# $$$$$$$$$$$$$
# $$$$$$$$$$$$$$
# $$$$$$$$$$$$$$$
# $$$$$$$$$
# $$$$$$$$$$
# $$$$$$$$$$$
# $$$$$$$$$$$$
# $$$$$$$$$$$$$
# $$$$$$$$$$$$$$
# $$$$$$$$$$$$$$$
# $$$$$$$$$$$$$$$$

# %% [markdown]
# ## DICTIONARY:
#     *  Curly brackets mein hai and in the form of "key:values"

# %%
list=[]
tuple=()
dict={} #dictionary=dict

# %%
##19 dict for keys, values, updating the key:values.
ananya={"school":"LMGC", "age":"18", "interest":"badminton"}
ananya.keys()
# Out:
# dict_keys(['school', 'age', 'interest'])

# %%
ananya.values()
# Out:
# dict_values(['LMGC', '18', 'badminton'])

# %%
ananya.update({"likes": "novels"})
ananya
# Out:
# {'school': 'LMGC', 'age': '18', 'interest': 'badminton', 'likes': 'novels'}

# %%
for keys, values in ananya.items():
    print(keys, ":" ,values)
# Out:
# school : LMGC
# age : 18
# interest : badminton
# likes : novels

# %% [markdown]
# ## SETS

# %%
#20 #it deletes the value which is taken twice as it only takes unique values into consideration
names= {"Ananya","mimo","sanjay","memo","mimo"}
names
# Out:
# {'Ananya', 'memo', 'mimo', 'sanjay'}

# %%
#21
list =[10, 20, 30, 40]
tuple =(10, 20, 30, 40)

# %%
list [0]= 2000
list
# Out:
# [2000, 20, 30, 40, 50, 60]

# %%
print (list, tuple)
# Out:
# [2000, 20, 30, 40, 50, 60] (10, 20, 30, 40, 50, 60)

# %%
list.insert(4, 10)

# %%
list
# Out:
# [2000, 20, 10, 10, 10, 100, 100, 30, 40, 50, 60]

# %% [markdown]
# ## TUPLE: IMMULATE

# %%
#22
tup=(10, 20, 30, 40)
tup
# Out:
# (10, 20, 30, 40)

# %%
#23
tup=tup2
tup2=()
tup2
# Out:
# ()

# %% [markdown]
# ## *ARGS(tuple) AND KWARGS(dict.)*

# %%
#24 (EXPLAIN THIS PLEASEEE)
## i mean how??

def students(*args, **kwargs):
    print(args)
    print(kwargs)

name=("sanjay","divya","karam")
info=[{'sanjay':'singh'},{'divya':'sharma'},{'karam':'babaji'}]
info2={'name':'john','age':'22'}

students(*name,**info2)
# Out:
# ('sanjay', 'divya', 'karam')
# {'name': 'john', 'age': '22'}

# %%
#25
