# %%
## VARIABLE, CONDTION, BOOLIAN, FUNCTIONS AND VISUAL STUDIO CODES

# %%
print("first")
print("second")
print("third")
# Out:
# first
# second
# third

# %%
def a():
    global x
    x= 1080
    print (x)

a()
print(x)
# Out:
# 1080
# 1080

# %%
##VARIABLES

# %%
x= 10
y= 20.5
name= "ananya"
id= "4b93"

id
# Out:
# '4b93'

# %%
## LIST: SQUARE BRACKETS 

x= []
x= [10, 20, 30, 40, 50]
x
y=[1, 2, 3, 4, 5, 6, 7, 8, 9]

y[0:7]
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
## ARRAY/LIST INDEXING

name="mimo_sanjay"
name[8]
# Out:
# 'j'

# %%
name[0:3]
# Out:
# 'mim'

# %%
name[0:11]
# Out:
# 'mimo_sanjay'

# %%
##CONDITIONALS
#IF/ELSE

#write a program to find if a number is even or not?
x= 58198
if x%2==0:
    print("even")

else:
    print("odd")
# Out:
# even

# %%
#write a program if the given person is eligible to vote
age=18
if age>18:
    print("yes")

else:
    print("no")
# Out:
# no

# %%
#write a program to check is the name is "ANU". if name is ANU print hi else bye
name= "ANU"
if name !="ANU":
    print("hi")
else:
    print("bye")
# Out:
# bye

# %%
## booleans
a= True
b= False
print(a, b)
# Out:
# True False

# %%
## FUNCTION TYPES

# %%
def area_square(l, b):
    ans=l*b
    return ans

# %%
def area_circle(a):
    pi= 3.14
    ans= pi*a*a
    return ans

# %%
area_square(0,10)
# Out:
# 10

# %%
area_circle(2)
# Out:
# 12.56

# %%
area_circle(int(input("enter radius")))
# Out:
# enter radius 92281
# 26739558497.54

# %%
length= int(input("enter l"))
breath= int(input("enter b"))
# Out:
# enter l 10
# enter b 30

# %%
breath
# Out:
# 30

# %%
## ASSIGNMENT:
-write a list variable that has string and float as values 
-write a function to add 3 numbers
-write a function to add strings (first name, second name)
-read about different logical operators in python and summarize them( max=5)
-read about different types of operators in python
-write a code using if/else to find which of 2 numbers is larger
-write a function to take your name as input
-write a list with input values as float/strings
-write a code for writing string values
-read the following code and find out what have been taught to you and how it fits
(https://www.kaggle.com/code/sanjaysinghgurjar122/transformers/edit)
-write the if else look of odd/even number inside a function
-write some code on your own, imagine something and try to write.....

# %%
## write a list variable that has str and float as values
x=["john", "mimo", 20.52, "Anu", 278.262]

# %%
##write a list with input values as float/strings
j= [20.363, "Sanjay", 28.28, "Anu"]

# %%
## write a function to add 3 numbers
def add(x, y, z):
    x = 20
    y = 20
    z = 30
    print(x+y+z)

add()
print(x+y+z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_35/2121122150.py in <cell line: 0>()
#       6     print(x+y+z)
#       7
# ----> 8 add()
#       9 print(x+y+z)
#
# TypeError: add() missing 3 required positional arguments: 'x', 'y', and 'z'

# %%
a= 20
b= 20
c= 20
print(a+b+c)
# Out:
# 60

# %%
def add_strings(p, q):
    p = "mimo"
    q = "memo"
    ans= p+a
    return ans

print(p+q)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_35/141301491.py in <cell line: 0>()
#       5     return ans
#       6
# ----> 7 print(p+q)
#
# NameError: name 'p' is not defined

# %%
## read about different logical operators in python and summarize them( max=5)
##read about different types of operators in python

# %%
##write a code using if/else to find which of 2 numbers are lager
f= 20
g=200
if f>g:
    print("F is greater")

else:
    print("G is greater")
# Out:
# G is greater

# %%
##write a function to take your name as input
def my_name():
    name= "Anu"

print("Hey " + name)
# Out:
# Hey ANU

# %%
##write a code for writing string values

# %%
##write the if else look of odd/even number inside a function
d= 298312
def even_odd():
    if d is odd:
        print("odd")
    else:
        print("even")
        
def even_odd():
    print(d)

# %%
##write some code on your own, imagine something and try to write. (but what?)
