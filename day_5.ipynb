# %% [markdown]
# ## METHODOLOGY: WHAT WHY HOW APPROACH
#     - READING FILES

# %%
f= open(' /kaggle/input/day-5-data/chat.txt','r')
print(f.name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_36/446768603.py in <cell line: 0>()
# ----> 1 f= open(' /kaggle/input/day-5-data/chat.txt','r')
#       2 print(f.name)
#
# FileNotFoundError: [Errno 2] No such file or directory: ' /kaggle/input/day-5-data/chat.txt'

# %%
f?
# Out:
# Object `f` not found.
