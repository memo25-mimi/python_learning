# %% [markdown]
# ## METHODOLOGY: WHAT WHY HOW APPROACH
#     - READING FILES

# %% [markdown]
# ## topics¶
#
# reading files*
#
# writing files*
#
# os*
#
# searching*
#
# sorting*
#
# visualization*
#
# assignment*

# %%
f= open(' / kaggle/input/day-5-data/chat/txt', 'r')
print(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_36/2418518361.py in <cell line: 0>()
# ----> 1 f= open(' / kaggle/input/day-5-data/chat/txt', 'r')
#       2 print(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: ' / kaggle/input/day-5-data/chat/txt'

# %%
f?
# Out:
# Object `f` not found.

# %%
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_36/4000743260.py in <cell line: 0>()
# ----> 1 f.close()
#
# NameError: name 'f' is not defined

# %%
with open(' /kaggle/input/day-5-data/chat.txt', 'r')  as f:
    print(f.read())
    f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_36/1431862597.py in <cell line: 0>()
# ----> 1 with open(' /kaggle/input/day-5-data/chat.txt', 'r')  as f:
#       2     print(f.read())
#       3     f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: ' /kaggle/input/day-5-data/chat.txt'

# %%
f=open('/kaggle/input/time-series-data-of-my-followers-on-studystream','r')
print(f.name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_36/855361252.py in <cell line: 0>()
# ----> 1 f=open('/kaggle/input/time-series-data-of-my-followers-on-studystream','r')
#       2 print(f.name)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/input/time-series-data-of-my-followers-on-studystream'

# %%
with open('/kaggle/input/time-series-data-of-my-followers-on-studystream/time_series_followers_on_ss - Sheet1.csv', 'r') as f:
    print(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_36/2511108327.py in <cell line: 0>()
# ----> 1 with open('/kaggle/input/time-series-data-of-my-followers-on-studystream/time_series_followers_on_ss - Sheet1.csv', 'r') as f:
#       2     print(f.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/input/time-series-data-of-my-followers-on-studystream/time_series_followers_on_ss - Sheet1.csv'

# %% [markdown]
# ## writing files

# %% [markdown]
# ## OS

# %%
import os
print(dir(os))
# Out:
# ['CLD_CONTINUED', 'CLD_DUMPED', 'CLD_EXITED', 'CLD_KILLED', 'CLD_STOPPED', 'CLD_TRAPPED', 'DirEntry', 'EFD_CLOEXEC', 'EFD_NONBLOCK', 'EFD_SEMAPHORE', 'EX_CANTCREAT', 'EX_CONFIG', 'EX_DATAERR', 'EX_IOERR', 'EX_NOHOST', 'EX_NOINPUT', 'EX_NOPERM', 'EX_NOUSER', 'EX_OK', 'EX_OSERR', 'EX_OSFILE', 'EX_PROTOCOL', 'EX_SOFTWARE', 'EX_TEMPFAIL', 'EX_UNAVAILABLE', 'EX_USAGE', 'F_LOCK', 'F_OK', 'F_TEST', 'F_TLOCK', 'F_ULOCK', 'GRND_NONBLOCK', 'GRND_RANDOM', 'GenericAlias', 'MFD_ALLOW_SEALING', 'MFD_CLOEXEC', 'MFD_HUGETLB', 'MFD_HUGE_16GB', 'MFD_HUGE_16MB', 'MFD_HUGE_1GB', 'MFD_HUGE_1MB', 'MFD_HUGE_256MB', 'MFD_HUGE_2GB', 'MFD_HUGE_2MB', 'MFD_HUGE_32MB', 'MFD_HUGE_512KB', 'MFD_HUGE_512MB', 'MFD_HUGE_64KB', 'MFD_HUGE_8MB', 'MFD_HUGE_MASK', 'MFD_HUGE_SHIFT', 'Mapping', 'MutableMapping', 'NGROUPS_MAX', 'O_ACCMODE', 'O_APPEND', 'O_ASYNC', 'O_CLOEXEC', 'O_CREAT', 'O_DIRECT', 'O_DIRECTORY', 'O_DSYNC', 'O_EXCL', 'O_FSYNC', 'O_LARGEFILE', 'O_NDELAY', 'O_NOATIME', 'O_NOCTTY', 'O_NOFOLLOW', 'O_NONBLOCK', 'O
# ...

# %%
print(os.getcwd())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_36/3072569317.py in <cell line: 0>()
# ----> 1 print(os.getcwd())
#
# NameError: name 'os' is not defined
