# %%
print("hello baby ")
# Out:
# hello baby

# %%
if 5 > 4:
    print ("Five is greater than Four!!")

if 10 > 2:
    print ("Ten is grater than two!!!!!")
# Out:
# Five is greater than Four!!
# Ten is grater than two!!!!!

# %%
x = "im sorry baby"
y = 10000

print(x)
print(y)
# Out:
# im sorry baby
# 10000

# %%
#this is a comment 
print("im sorry baby")

print("im sorry") #this is a comment
#print("hey my love")
print("im sorry")
# Out:
# im sorry baby
# im sorry
# im sorry

# %%
"""hehehehe how r u"""
print ("hey you mr. coder")
#i know im stupid
#i know i hurt you
#but i dont want you to leave 
print("im sorry")
# Out:
# hey you mr. coder
# im sorry

# %%
x = "BABY"
y = "im sorry"
z = 100

print(x)
print(y)
print(z)
# Out:
# BABY
# im sorry
# 100

# %%
x = 4 #x is of type int
x = "sally" #x is a now a type str
print(x)
# Out:
# sally

# %%
x = str(4) #x wil be 4
y = int(4) #y will be 4
z = float(3) #z will be 3.0
print (x)
print(y)
print(z)
# Out:
# 4
# 4
# 3.0

# %%
x= 100
y= "sanjay ananya"
print (type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x= "john"
x= 'john'
#double quotes and single quotes are the same
print(x)
# Out:
# john

# %%
a= 2
A= "i"
b= "love"
B= "you"
#A will not overwrite a
print(A)
print(b)
print(B)
print(a)
# Out:
# i
# love
# you
# 2

# %%
hey = "mimo"
_hey = "anu"
HELLO = "john"

print(hey)
print(_hey)
print(HELLO)
# Out:
# mimo
# anu
# john

# %%
thisIsTheVariableName = "SANJAY"
this_is_my_name = "ananya"
ThisIsMyName = "SJandANANYA"
123 = "sanjay"

print(thisIsTheVariableName)
print(this_is_my_name)
print(ThisIsMyName)
print(123)
# Out:
#   File "/tmp/ipykernel_35/4068835204.py", line 4
#     123 = "sanjay"
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
a, b, c = "apple", "banana", "mango"
print(a)
print(b)
print(c)
# Out:
# apple
# banana
# mango

# %%
x = y = z = "romance"
print (x)
print(y)
print(z)
# Out:
# romance
# romance
# romance

# %%
fruits= ["apple", "banana", "cherry", "strawberry"]
a, b, c, d = fruits
print(a)
print(b)
print(c)
print(d)
# Out:
# apple
# banana
# cherry
# strawberry

# %%
x = "i love my family"
print (x)

a = "i "
b = "love "
c = "my "
d = "family "
print (a, b, c, d)
print (a + b + c + d)
# Out:
# i love my family
# i  love  my  family
# i love my family

# %%
x = 20
y = 10
print (x + y)
print (x - y)

a = 5
b = "mimo"
print (a, b)
# Out:
# 30
# 10
# 5 mimo

# %%
x = "awesome"
def myfunc():
    x = "confusing"
    print ("Python is " + x)

myfunc()

print("python is " + x)
# Out:
# Python is confusing
# python is awesome

# %%
x = "awesome"
def myfunc():
    x = "fantastic"
    print("python is " + x)

myfunc()

print("pythong is " + x)
# Out:
# python is fantastic
# pythong is awesome

# %%
def add(a, b, c, d ,e):
    
    return(a+b+c+d+e)

add(1, 1, 1, 1, 1)
# Out:
# 5
