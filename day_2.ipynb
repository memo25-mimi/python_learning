# %% [markdown]
# ## basic kaggle cammands
# - esc+a:add new cell above
# - esc+b: add new cell below
# - dd: delete cell
# - ctrl+enter: run current cell
# - shift+enter : run current cell and move onto next cell
# - esc+m: markdown
# - esc+c: code

# %%
#global variables 
x = "fantastic"

def myfunc():
    x= "cute"
    print("Python is " + x)

myfunc()

print ("PYTHON IS " +x)
# Out:
# Python is cute
# PYTHON IS fantastic
